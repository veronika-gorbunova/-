# %%
import numpy as np
import cv2  as cv
import matplotlib.pyplot as plt

# %%
croped_image = cv.imread('vg.jpg')
rgb_image = cv.cvtColor(image, cv.COLOR_BGR2RGB)
rgb_image = 1 - rgb_image
plt.imshow(rgb_image)
